# %% [markdown]
# # **Project Name**    - Retail Sales Prediction(Rossmann)

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Chetan Gode

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
#                 Rossmann operates over 3000 drug store in 7 European countries. Currently Rossmann Store Manager are tasked with predicting their daily sales for up to six week in advance. Store sales are influenced by many factors, including Promotions,Competition, School and State holidays,Seasonality and locality.with thousand individual managers predicting sales based on their unique circumstances,the accuracy of results can be quite varied.
#                 We have provided with historical sales data fo 1115 rossmann store and task is to forecast Sales.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/chetansgode/Rossmann_Retail_Sales_prediction.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# * **we have historical sales data for 1115 rossmann store and task is to forecast Sales and note that some store in dataset were temporary closed for refurbishment.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np  #importing numpy library
import pandas as pd  #importing pandas library

# for visualisation import matplotlib and seaborn
import matplotlib.pyplot as plt  
# %matplotlib inline
# %lsmagic
import seaborn as sns

#importing sklearn packages for ml

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,RidgeCV
from sklearn.linear_model import Lasso ,LassoCV
from sklearn.metrics import r2_score,mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df_store=pd.read_csv('C:/Users/Admin/Downloads/store (1).csv')
df_sales=pd.read_csv('C:/Users/Admin/Downloads/Rossmann Stores Data (1).csv',parse_dates=['Date'])

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look for store
df_store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
# Dataset First Look for Sales
df_sales.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

df_store.shape
# Out:
# (1115, 10)

# %%
df_sales.shape
# Out:
# (1017209, 9)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info for store
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
# Dataset Info for Sales
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  datetime64[ns]
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 69.8+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count for Store
df_store.duplicated().sum()
# Out:
# 0

# %%
# Dataset Duplicate Value Count for Sales
df_sales.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count for Store data
for i in df_store.columns:
    print( i,' has null value : ',df_store[i].isna().sum())
# Out:
# Store  has null value :  0
# StoreType  has null value :  0
# Assortment  has null value :  0
# CompetitionDistance  has null value :  3
# CompetitionOpenSinceMonth  has null value :  354
# CompetitionOpenSinceYear  has null value :  354
# Promo2  has null value :  0
# Promo2SinceWeek  has null value :  544
# Promo2SinceYear  has null value :  544
# PromoInterval  has null value :  544

# %%
# Missing Values/Null Values Count for Sales data
for i in df_sales.columns:
    print( i,' has null value : ',df_sales[i].isna().sum())   #no missing value in Sales data
# Out:
# Store  has null value :  0
# DayOfWeek  has null value :  0
# Date  has null value :  0
# Sales  has null value :  0
# Customers  has null value :  0
# Open  has null value :  0
# Promo  has null value :  0
# StateHoliday  has null value :  0
# SchoolHoliday  has null value :  0

# %%
# Visualizing the missing values for store data

for i in df_store.columns:
    plt.gca()
    # Calculate the counts of NaN and non-NaN values
    na_count = df_store[i].isna().sum()
    non_na_count = df_store[i].notna().sum()
    
    if na_count != 0: #To visualize only na value chart.

        # Create a list of values
        values = [na_count, non_na_count]

        # Create labels for the pie chart
        labels = ['NaN', 'Non-NaN']

        # Plot the pie chart
        plt.pie(values, labels=labels , autopct='%.1f%%')
        plt.title(f'missing value in {i}')

        # Display the chart
        plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
# * In Sales data :-
# ** Not present any duplicate data and missing value too.
# * In Store data:-
# ** Not present any duplicate data but there have many missing data in features.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns for sales

df_sales.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
# Dataset Columns for store
df_store.columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
# Dataset Describe for sales
df_sales.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# ...

# %%
# Dataset Describe for store
df_store.describe()
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1112.000000                 761.000000
# mean    558.00000          5404.901079                   7.224704
# std     322.01708          7663.174720                   3.212348
# min       1.00000            20.000000                   1.000000
# 25%     279.50000           717.500000                   4.000000
# 50%     558.00000          2325.000000                   8.000000
# 75%     836.50000          6882.500000                  10.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count                761.000000  1115.000000       571.000000       571.000000
# mean                2008.668857     0.512108        23.595447      2011.763573
# std                    6.195983     0.500078        14.141984         1.674935
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * store-Store_id
# * Sales-Sales made for the day
# * Customers - Footfall for the day
# * Open-Open or close
# * StateHoliday- State holiday or not
# * SchoolHoliday - School holiday or not
# * StoreType - Types of store
# * Assortment-Type of assortment
# * CompetitionDistance-Distance from nearest competition
# * Promo- Store running promotion or not
# * Promo2-Store running consecutive promotion or not
# * PromoInterval-Promotion intervals

# %% [markdown]
# ### Merge Data set (Available)

# %%
#merge 2 data file on store by left joining

df=pd.merge(df_store,df_sales,how='left',on='Store')
df.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      1         c          a               1270.0                        9.0
# 2      1         c          a               1270.0                        9.0
# 3      1         c          a               1270.0                        9.0
# 4      1         c          a               1270.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2008.0       0              NaN              NaN
# 2                    2008.0       0              NaN              NaN
# 3                    2008.0       0              NaN              NaN
# 4                    2008.0       0              NaN              NaN
#
#   PromoInterval  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# ...

# %%
df.shape
# Out:
# (1017209, 18)

# %%
#store column no need for further calculation so drop it
df.drop('Store',axis=1,inplace=True)
df.shape
# Out:
# (1017209, 17)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable (no unique value,unique value,unique value count)

for n,i in enumerate( df.columns):
    no_unique_values = df[i].nunique()
    unique_values =df[i].unique()
    unique_value_counts =df[i].value_counts()
    print(f"{n+1}- for {i} column No of unique values is :- \n{no_unique_values},\n unique values is:-\n{unique_values},\n No of unique value counts:-\n{unique_value_counts}")
# Out:
# 1- for StoreType column No of unique values is :-
# 4,
#  unique values is:-
# ['c' 'a' 'd' 'b'],
#  No of unique value counts:-
# a    551627
# d    312912
# c    136840
# b     15830
# Name: StoreType, dtype: int64
# 2- for Assortment column No of unique values is :-
# 3,
#  unique values is:-
# ['a' 'c' 'b'],
#  No of unique value counts:-
# a    537445
# c    471470
# b      8294
# Name: Assortment, dtype: int64
# 3- for CompetitionDistance column No of unique values is :-
# 654,
#  unique values is:-
# [1.270e+03 5.700e+02 1.413e+04 6.200e+02 2.991e+04 3.100e+02 2.400e+04
#  7.520e+03 2.030e+03 3.160e+03 9.600e+02 1.070e+03 1.300e+03 4.110e+03
#  3.270e+03 5.000e+01 1.384e+04 3.240e+03 2.340e+03 5.500e+02 1.040e+03
#  4.060e+03 4.590e+03 4.300e+02 2.300e+03 6.000e+01 1.200e+03 2.170e+03
#  4.000e+01 9.800e+03 2.910e+03 1.320e+03 2.240e+03 7.660e+03 5.400e+02
#  4.230e+03 1.090e+03 2.600e+02 1.800e+02 1.180e+03 2.900e+02 4.880e+03
# ...

# %%
Stateholiday_before=df['StateHoliday'].unique()
df['StateHoliday'].replace({'0':0},inplace=True)
StateHoliday_after=df['StateHoliday'].unique()
print('Stateholiday_before ',Stateholiday_before)
print('StateHoliday_after ',StateHoliday_after)
# Out:
# Stateholiday_before  ['0' 'a' 'b' 'c' 0]
# StateHoliday_after  [0 'a' 'b' 'c']

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
#  Write your code to make your dataset analysis ready.

# %%
# Firstly We will replace all null value
for i in ['CompetitionDistance','CompetitionOpenSinceMonth','CompetitionOpenSinceYear','Promo2SinceWeek','Promo2SinceYear']:
    plt.figure(figsize=(5,5))
    plt.subplot(1,2,1)
    sns.distplot(df[i],bins=50)
    plt.title(i + 'distibution plot')
    plt.subplot(1,2,2)
    sns.scatterplot(x=df[i],y=df['Sales'],data=df)
    plt.title('scatterplot between' + i + " and sales" )

    plt.show()

# %%
# Replace CompetitionDistance none value with median value because right skew data
df['CompetitionDistance'].fillna(df['CompetitionDistance'].median(),inplace=True)

# %%
# Replace all other null features data with 0

for i in ['CompetitionOpenSinceMonth','CompetitionOpenSinceYear','Promo2SinceWeek','Promo2SinceYear','PromoInterval']:
    df[i].fillna(0,inplace=True)

# %%
# See final  data if any null data present or not

for i in df.columns:
    print( i,' has null value : ',df[i].isna().sum())
# Out:
# StoreType  has null value :  0
# Assortment  has null value :  0
# CompetitionDistance  has null value :  0
# CompetitionOpenSinceMonth  has null value :  0
# CompetitionOpenSinceYear  has null value :  0
# Promo2  has null value :  0
# Promo2SinceWeek  has null value :  0
# Promo2SinceYear  has null value :  0
# PromoInterval  has null value :  0
# DayOfWeek  has null value :  0
# Date  has null value :  0
# Sales  has null value :  0
# Customers  has null value :  0
# Open  has null value :  0
# Promo  has null value :  0
# StateHoliday  has null value :  0
# SchoolHoliday  has null value :  0

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
# We know that some feature has null value so replaced it as following.
# *  CompetitionDistance  has null value :  3           by median value
# *  CompetitionOpenSinceMonth  has null value :  354   by 0
# *  CompetitionOpenSinceYear  has null value :  354    by 0
# *  Promo2SinceWeek  has null value :  544             by 0
# *  Promo2SinceYear  has null value :  544             by 0
# *  PromoInterval  has null value :  544               by 0

# %% [markdown]
# ## ***4. Data Visualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1-check sales with respect to store type and then assortment

# %%
print(df.groupby(['StoreType'])['Sales'].mean().sort_values(ascending=True))
print('--'*20)
print(df.groupby(['Assortment'])['Sales'].mean().sort_values(ascending=True))
print('--'*20)
print(df.groupby(['StoreType','Assortment'])['Sales'].mean().unstack())
# Out:
# StoreType
# d     5641.819243
# c     5723.629246
# a     5738.179710
# b    10058.837334
# Name: Sales, dtype: float64
# ----------------------------------------
# Assortment
# a    5481.026096
# c    6058.676567
# b    8553.931999
# Name: Sales, dtype: float64
# ----------------------------------------
# Assortment             a            b             c
# StoreType
# a            5398.858310          NaN   6310.867032
# b           10821.619806  8553.931999  17969.556263
# c            5647.174314          NaN   5805.782193
# d            5317.885943          NaN   5826.407660

# %%
# Chart - 1 visualization code-check sales with respect to store type and then assortment
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
df.groupby(['StoreType'])['Sales'].mean().sort_values(ascending=True).plot(kind='bar')
plt.title("StoreType vs Sales")
plt.xlabel('Storetype')
plt.ylabel('Mean Sales')


plt.subplot(1,3,2)
df.groupby(['Assortment'])['Sales'].mean().sort_values(ascending=True).plot(kind='bar')
plt.title("Assortment vs Sales")
plt.xlabel('Assortment')
plt.ylabel('Mean Sales')

plt.subplot(1,3,2)
df.groupby(['StoreType','Assortment'])['Sales'].mean().unstack().plot(kind='bar')
plt.title('StoreType and Assortment vs Sales')
plt.xlabel('Assortment and StoreType')
plt.ylabel('Mean Sales')

plt.tight_layout()  # Adjust spacing between subplots

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# * To Visualize data easily

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# * StoreType b has highest sales among all and assortment b has highest sales
# * StoreType b is selling highest amount of assortment c and lowest b
# * Assortment b is only available in StoreType b

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# * Yes
# * Assortment b only available in store type b need to available to another store too.

# %% [markdown]
# #### Chart - 2-Check Sales with respect to Distances

# %%
# Categorised the distance into 3 buckets because there are two many distances
"""
Distance <2000 :- 0 (min)
Distance > 4000 :- 2 (max)
distance in between 2000 and 4000 :- 1 (med)"""

df['distance']=df['CompetitionDistance'].apply(lambda x :0 if x<2000 else(1 if 2000<=x>4000 else 2 ))

# No need of CompetitionDistance columns now so drop it.
df.drop('CompetitionDistance',axis=1,inplace=True)

# %%
# sales valume 
df.groupby('distance')['Sales'].mean()
# Out:
# distance
# 0    6006.683067
# 1    5678.878023
# 2    5393.679697
# Name: Sales, dtype: float64

# %%
# Chart - 2 visualization code
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.distplot(df['distance'].value_counts(),hist=True)
plt.title('distplot of Distance')

plt.subplot(1,3,2)
sns.boxplot(x=df['distance'],y=df['Sales'])
plt.title('box plot distance vs sales')

plt.subplot(1,3,3)
df.groupby('distance')['Sales'].mean().plot(kind='bar')
plt.title('Distance vs Sales')
plt.xlabel('Distance')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# * To check sales distribution

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# * With minimum (0) or  competition distance less than 2000 then sales is highest and as distance increase sales go down

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# * With less competition distance sales is highest as compare to midum and max distance

# %% [markdown]
# #### Chart - 3- Check sales with respect to CompetitionOpenSinceMonth

# %%
#Check value count of CompetitionOpenSinceMonth
print(df['CompetitionOpenSinceMonth'].value_counts().sort_index())
print('--'*20)

#Check sales with respect to CompetitionOpenSinceMonth
df.groupby('CompetitionOpenSinceMonth')["Sales"].mean()
# Out:
# 0.0     323348
# 1.0      12452
# 2.0      37886
# 3.0      63548
# 4.0      87076
# 5.0      39608
# 6.0      45444
# 7.0      59434
# 8.0      36186
# 9.0     114254
# 10.0     55622
# 11.0     84455
# 12.0     57896
# Name: CompetitionOpenSinceMonth, dtype: int64
# ----------------------------------------
# CompetitionOpenSinceMonth
# 0.0     5758.628326
# 1.0     6172.995021
# 2.0     5429.783060
# 3.0     6018.509804
# 4.0     5721.389568
# 5.0     6253.914209
# 6.0     6355.309018
# 7.0     5605.731231
# 8.0     6242.269193
# 9.0     5674.837021
# 10.0    5672.669411
# 11.0    5482.371736
# 12.0    5620.760761
# Name: Sales, dtype: float64

# %%
# Chart - 3 visualization code-CompetitionOpenSinceMonth vs sales
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
ax=plt.gca()
df['CompetitionOpenSinceMonth'].value_counts().sort_index().plot(kind='bar')
ax.axhline(df['CompetitionOpenSinceMonth'].value_counts().mean(),color='red',linestyle='dashed')
ax.axhline(df['CompetitionOpenSinceMonth'].value_counts().median(),color='orange',linestyle='dashed')
plt.title('value_count for CompetitionOpenSinceMonth')
plt.xlabel('Since Month')
plt.ylabel('Value counts')

plt.subplot(1,2,2)
ax=plt.gca()
df.groupby('CompetitionOpenSinceMonth')["Sales"].mean().plot(kind='bar')
ax.axhline(df["Sales"].mean(),color='red',linestyle='dashed')
ax.axhline(df["Sales"].median(),color='orange',linestyle='dashed')
plt.title('Sales vs CompetitionOpenSinceMonth')
plt.xlabel('Since month')
plt.ylabel('Sales')
plt.show()

# Plotting the first graph
plt.plot(df['CompetitionOpenSinceMonth'].value_counts().sort_index(), label='Graph 1')
# Plotting the second graph
plt.plot(df.groupby('CompetitionOpenSinceMonth')["Sales"].mean(), label='Graph 2')
# Adding labels and title
plt.xlabel('Competition Open Since Month')
plt.ylabel('Mean Sales\\value count')
plt.title('Overlay of Graph 1 and Graph 2')
# Displaying the legend
plt.legend()
# Displaying the overlapped graph
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# * To check trend of competition open since month

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# * Sales in between range not much change the trend by increasing competition or vice versa.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# * Competiton open are not affecting mean sales

# %% [markdown]
# #### Chart - 4-- Check sales with respect to CompetitionOpenSinceYear

# %%
#Check value count of CompetitionOpenSinceYear
print(df['CompetitionOpenSinceYear'].value_counts().sort_index())
print('--'*20)

#Check sales with respect to CompetitionOpenSinceYear
df.groupby('CompetitionOpenSinceYear')["Sales"].mean()
# Out:
# 0.0       323348
# 1900.0       758
# 1961.0       942
# 1990.0      4710
# 1994.0      1884
# 1995.0      1700
# 1998.0       942
# 1999.0      7352
# 2000.0      9236
# 2001.0     14704
# 2002.0     24882
# 2003.0     16794
# 2004.0     19804
# 2005.0     56564
# 2006.0     42802
# 2007.0     43744
# 2008.0     48476
# 2009.0     49396
# 2010.0     51258
# 2011.0     49396
# 2012.0     74299
# 2013.0     75426
# 2014.0     63732
# 2015.0     35060
# Name: CompetitionOpenSinceYear, dtype: int64
# ----------------------------------------
# CompetitionOpenSinceYear
# 0.0       5758.628326
# 1900.0    6889.460422
# 1961.0    6460.928875
# 1990.0    5915.546921
# 1994.0    5987.539809
# 1995.0    6160.058824
# 1998.0    6091.211253
# 1999.0    5698.102557
# 2000.0    6515.340082
# 2001.0    5323.590860
# 2002.0    5473.457319
# 2003.0    5788.870966
# 2004.0    5224.698192
# 2005.0    5659.650997
# 2006.0    5787.615999
# 2007.0    5449.721928
# 2008.0    5597.502310
# ...

# %%
# Chart - 4 visualization code-CompetitionOpenSinceYear vs sales
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
ax=plt.gca()
df['CompetitionOpenSinceYear'].value_counts().sort_index()[1:].plot(kind='bar')   #just ignoring zero value for better visualization
ax.axhline(df['CompetitionOpenSinceYear'].value_counts().mean(),color='red',linestyle='dashed')
ax.axhline(df['CompetitionOpenSinceYear'].value_counts().median(),color='orange',linestyle='dashed')
plt.title('value_count for CompetitionOpenSinceYear')
plt.xlabel('Since Month')
plt.ylabel('Value counts')

plt.subplot(1,2,2)
ax=plt.gca()
df.groupby('CompetitionOpenSinceYear')["Sales"].mean()[1:].plot(kind='bar')  #just ignoring zero value for better visualization
ax.axhline(df["Sales"].mean(),color='red',linestyle='dashed')
ax.axhline(df["Sales"].median(),color='orange',linestyle='dashed')
plt.title('Sales vs CompetitionOpenSinceYear')
plt.xlabel('Since month')
plt.ylabel('Sales')
plt.show()

# Plotting the first graph
plt.plot(df['CompetitionOpenSinceYear'].value_counts().sort_index(), label='Graph 1')
# Plotting the second graph
plt.plot(df.groupby('CompetitionOpenSinceYear')["Sales"].mean(), label='Graph 2')
# Adding labels and title
plt.xlabel('Competition Open Since Year')
plt.ylabel('Mean Sales\\value count')
plt.title('Overlay of Graph 1 and Graph 2')
# Displaying the legend
plt.legend()
# Displaying the overlapped graph
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# * To easy visualization

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# * Year on Year competition are increased but demand is constant at range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# * Yes above chart showing that competition incresed year on year but sales not increase as competition.
# * Need to find new market

# %% [markdown]
# #### Chart - 5- Check sales with respect to 'Promo2', 'Promo2SinceWeek','Promo2SinceYear',

# %%
# promo2sinceweek has to many unique value for further calculation we convert it into bucket 10week in a group like that.
df['Promo2SinceWeek']=df['Promo2SinceWeek'].apply(lambda x : 1 if x < 10 else(2 if 10<=x<20 else(3 if 20<=x<30 else(4 if 30<=x<40 else 5))))

for i in ['Promo2', 'Promo2SinceWeek','Promo2SinceYear']:
    print(df.groupby(i)['Sales'].mean())
# Out:
# Promo2
# 0    6124.710161
# 1    5423.718218
# Name: Sales, dtype: float64
# Promo2SinceWeek
# 1    5982.367704
# 2    5364.576251
# 3    5224.368473
# 4    5479.843880
# 5    5801.091070
# Name: Sales, dtype: float64
# Promo2SinceYear
# 0.0       6124.710161
# 2009.0    5761.243312
# 2010.0    5446.156810
# 2011.0    5484.207516
# 2012.0    5298.761063
# 2013.0    4900.741690
# 2014.0    5916.283627
# 2015.0    5124.890963
# Name: Sales, dtype: float64

# %%
# Chart - 5 visualization code sales vs Promo2,Promo2SinceWeek,Promo2SinceYear
for i in ['Promo2', 'Promo2SinceWeek','Promo2SinceYear']:
    if i=='Promo2SinceWeek':
        plt.figure(figsize=(10,5))
        sns.barplot(df[i],df['Sales'])
        plt.show()
    else:
        plt.figure(figsize=(5,5))
        sns.barplot(df[i],df['Sales'])
        plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# * To visualize easily trend of promo.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# * Without promo2 also sales is high.
# * Promo2 since week increases Sales lightly upwards.
# * Promo2 since year not much helpfull.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# * Promo2 since week only help to increase sales among all.

# %% [markdown]
# #### Chart - 6- to check sales with respect to PromoInterval, DayOfWeek, and Date

# %%
#Convert string of catgorical value of feature PromoInterval into 0, 'Jan,Apr,Jul,Oct' :-1, 'Feb,May,Aug,Nov':-2, 'Mar,Jun,Sept,Dec':-3

df['PromoInterval']=df['PromoInterval'].apply(lambda x : 1 if x=='Jan,Apr,Jul,Oct' else(2 if x =='Feb,May,Aug,Nov' else(3 if x== 'Mar,Jun,Sept,Dec' else 0) ))
print(df['PromoInterval'].value_counts())

#To find sales with respect to day

print(df.groupby('DayOfWeek')['Sales'].mean())

# to find sales with respect to year and month

print(df.groupby([df['Date'].dt.year,df['Date'].dt.month])['Sales'].mean().unstack())
# Out:
# 0    508031
# 1    293122
# 2    118596
# 3     97460
# Name: PromoInterval, dtype: int64
# DayOfWeek
# 1    7809.044510
# 2    7005.244467
# 3    6555.884138
# 4    6247.575913
# 5    6723.274305
# 6    5847.562599
# 7     204.183189
# Name: Sales, dtype: float64
# Date           1            2            3            4            5   \
# Date
# 2013  5211.555578  5494.371397  5820.349168  5483.749836  5364.127383
# 2014  5431.875799  5731.091512  5584.257312  5815.993333  5632.670534
# 2015  5752.747866  5710.296541  5949.130132  5916.857578  5472.122002
#
# Date           6            7            8            9            10  \
# Date
# 2013  5402.162960  6042.062260  5729.574049  5322.988430  5429.258788
# 2014  5681.526188  5999.403381  5649.421252  5865.104029  5665.564878
# 2015  6199.203976  6142.705511          NaN          NaN          NaN
#
# Date           11           12
# Date
# 2013  5864.601614  6703.618140
# 2014  6179.249661  6973.282456
# ...

# %%
# Chart - 6 visualization code-sales with respect to PromoInterval, DayOfWeek, and Date
for i in ['PromoInterval','DayOfWeek']:
    sns.barplot(x=df[i],y=df['Sales'])
    plt.title(i + ' vs sales')
    plt.show()

    
plt.figure(figsize=(5,5))

df.groupby(df['Date'].dt.year)['Sales'].mean().plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('mean sales')
plt.title('Year vs Sales')
plt.show()

plt.figure(figsize=(45,5))
df.groupby([df['Date'].dt.year,df['Date'].dt.month])['Sales'].mean().unstack().plot(kind='bar',width=0.9)
plt.xlabel('Year and month')
plt.ylabel('mean sales')
plt.title('Year and month vs Sales')
plt.legend(title='Month')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# * To compare sales volume.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
# * Higher sales during PromoInterval-1 (ie.'Jan,Apr,Jul,Oct') and it is decreases simulteneously with other.
# * Highest sales on day 1 (ie. Monday) and lowest on 7 (ie.Sunday)
# * Year on year sales is slightly increasing.
# * At the end of year sales is highest

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# * yes
# * There is lowest sales on day 7 ie Sunday (so we may close shop on Sunday)

# %% [markdown]
# #### Chart - 7-check sales vs ('Customers', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday')

# %% [markdown]
# * There is lots of unique customer sales volume,not easy to visualize so bucketize the customer with respect to sales as follows.
#
# * Sales < 5000             :- 0
# * 5,000 <= Sales <10,000   :- 1
# * 10,000 <= Sales <15,000  :- 2
# * 15,000 <= Sales <20,000  :- 3
# * 20,000 <= Sales <25,000  :- 4
# * 25,000 <= Sales <30,000  :- 5
# * 30,000 < Sales           :- 6

# %%
# So classified customer with respect to sales
df['Customers'] = df.groupby('Customers')['Sales'].mean().apply(lambda x : 0 if x<5000 else(1 if 5000 <= x < 10000 else(2 if 10000<= x < 15000 else(3 if 15000<=x<20000 else(4 if 20000 <= x < 25000 else(5 if 25000 <= x<30000 else 6 )))) ))
print(df['Customers'].value_counts())
print('--'*25)

for i in ['Customers','Open', 'Promo', 'StateHoliday', 'SchoolHoliday']:
    print(df.groupby(i)['Sales'].mean())
    print('--'*25)
# Out:
# 3.0    1356
# 2.0    1130
# 1.0     660
# 0.0     430
# 4.0     257
# 5.0     164
# 6.0      89
# Name: Customers, dtype: int64
# --------------------------------------------------
# Customers
# 0.0    3847.027907
# 1.0    4067.443939
# 2.0    4863.805310
# 3.0    6777.766962
# 4.0    6419.766537
# 5.0    4144.530488
# 6.0    4100.382022
# Name: Sales, dtype: float64
# --------------------------------------------------
# Open
# 0       0.000000
# 1    6955.514291
# Name: Sales, dtype: float64
# --------------------------------------------------
# Promo
# 0    4406.050805
# 1    7991.152046
# Name: Sales, dtype: float64
# --------------------------------------------------
# StateHoliday
# 0    5947.483893
# a     290.735686
# b     214.311510
# c     168.733171
# Name: Sales, dtype: float64
# --------------------------------------------------
# SchoolHoliday
# 0    5620.979034
# 1    6476.522207
# Name: Sales, dtype: float64
# --------------------------------------------------

# %%
# Chart - 7 visualization code
for i in ['Customers','Open', 'Promo', 'StateHoliday', 'SchoolHoliday']:
    sns.barplot(x=df[i],y=df['Sales'])
    plt.title(i + 'vs Sales')
    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# * To Easily understanding critical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# * the highest sales for customer 3 ( ie.15,000 <= Sales <20,000 )

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# * Yes.
# * with Promo sales is highest.
# * Sales is more during school holiday.

# %% [markdown]
# #### Chart - 8 - Correlation Heatmap

# %%
# Copy data frame to another data frame for correlation calculation
df1=df.copy()

# %%
#for heatmap convert convert all variable into numerical form
df1['StoreType']=df1['StoreType'].apply(lambda x : 0 if x=='a' else(1 if x=='b' else (2 if x=='c' else 3)))
df1['Assortment']=df1['Assortment'].apply(lambda x : 0 if x=='a' else(1 if x=='b' else 3))
df1['StateHoliday']=df1['StateHoliday'].apply(lambda x : 1 if x== 'a' else(2 if x=='b' else(3 if x=='c' else 0)))
df1.drop('Date',axis=1,inplace=True)

# %%
# # Correlation Heatmap visualization code
plt.figure(figsize=(20,20))
sns.heatmap(abs(df1.corr()) ,annot=True,cmap="coolwarm")
plt.title("correlation heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# * Showing relation between each features

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# * The realation between each feature is showing in above chart.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
plt.title('Pairplot')
sns.pairplot(data=df1)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# * To show directly plot of one feature with respect to all.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# * Distribution of value of one feature with respect to other is directly showing in above chart.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
